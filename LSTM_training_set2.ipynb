# %%
import numpy as np
from preprocess import *
import pandas as pd

train_path = './essay_dataset/training_set_rel3.tsv'
training_data = load_training_set(train_path, 2)

glove_dict = load_dict('glove.840B.300d.pkl')

# %%
valid_path = './essay_dataset/valid_set.tsv'
valid_label_path = './essay_dataset/valid_sample_submission_2_column.csv'
valid_data = load_validation_set(valid_path, valid_label_path, 2)

# %%
training_data = process_scores(training_data, 'domain1_score')
valid_data = process_scores(valid_data, 'domain1_score')

# %%
from configs import cfg

cfg['input_dim'] = 301 # input dimension to LSTM
cfg['hidden_dim'] = 128 # hidden dimension for LSTM
cfg['output_dim'] = 1 # output dimension of the model
cfg['layers'] = 2 # number of layers of LSTM

cfg['dropout'] = 5e-3 # dropout rate between two layers of LSTM; useful only when layers > 1; between 0 and 1
cfg['bidirectional'] = True # True or False; True means using a bidirectional LSTM
cfg['batch_size'] = 120 # batch size of input
cfg['learning_rate'] = 1e-3 # learning rate to be used
cfg['L2_penalty'] = 1e-4 # weighting constant for L2 regularization term; this is a parameter when you define optimizer
cfg['epochs'] = 20 # number of epochs for which the model is trained
cfg['embed'] = False
cfg['score_range'] = 3

# %%
from dataloader import *
from models import *
import time

model = LSTM_Score(cfg, True)

#model = RNN(vocab_size=vocab_size, embed_size=args.embedding_size, num_output=10, rnn_model=args.rnn,
#            use_last=( not args.mean_seq),
#            hidden_size=args.hidden_size, embedding_tensor=embed, num_layers=args.layers, batch_first=True)
model = model.to(torch.device(cfg['device']))

criterion = nn.MSELoss()

#optimizer = torch.optim.RMSprop(model.parameters(), lr=cfg['learning_rate'], weight_decay=cfg['L2_penalty'])
optimizer = torch.optim.Adam(model.parameters(), lr=cfg['learning_rate'], weight_decay=cfg['L2_penalty'])
#optimizer = torch.optim.Adadelta(model.parameters(), lr=cfg['learning_rate'], weight_decay=cfg['L2_penalty'])

train_indices = list(range(len(training_data)))
valid_indices = list(range(len(valid_data)))

print('ready')
# Out:
# ready

# %%
model.train()
# Out:
# LSTM_Score(
#   (embed_linear): Linear(in_features=301, out_features=301, bias=True)
#   (conv): Conv1d(120, 120, kernel_size=(5,), stride=(1,), padding=(2,))
#   (lstm): LSTM(301, 128, num_layers=2, batch_first=True, dropout=0.005, bidirectional=True)
#   (bn): BatchNorm1d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=256, out_features=1, bias=True)
# )

# %%
train_losses = []
val_losses = []
for epoch in range(cfg['epochs']):
    tloader = DataLoader(training_data, train_indices, cfg, glove_dict)
    vloader = DataLoader(valid_data, valid_indices, cfg, glove_dict)
    
    count = 0
    avg_loss = 0
    while tloader.has_next():
        train, label, lengths = tloader.get_next()
        #print(train.size())
        #print(label.size())
        #print(lengths.size())
        model.zero_grad()
        
        y = model(train, lengths)      
        
        loss = criterion(y*cfg['score_range'], label*cfg['score_range'])
        loss.backward()
        optimizer.step()

        count += 1
        avg_loss += loss.item()
        if count % 2 == 0:
            print("count = %d, loss = %.5f" %(count, avg_loss / 2))
            save_model(model, 'models/'+'s1_ba' +str(cfg['batch_size']) +'e' +  str(epoch + 1) + 'b' + str(count) + '.pt')
            train_losses.append(avg_loss/2)
            avg_loss = 0
        del train, label, y, loss
    
    count = 0
    avg_loss = 0
    with torch.no_grad():
        while vloader.has_next():
            train, label, lengths = vloader.get_next()
            y = model(train, lengths)
            loss = criterion(y*cfg['score_range'], label*cfg['score_range'])
            count += 1
            avg_loss += loss.item()
            del train, label, y, loss
    print('validation loss:', avg_loss / count)
    print('epoch finished:', epoch + 1)
    val_losses.append(avg_loss/count)
# Out:
# count = 2, loss = 0.58608
# count = 4, loss = 0.45828
# count = 6, loss = 0.17450
# count = 8, loss = 0.16160
# count = 10, loss = 0.11943
# count = 12, loss = 0.10404
# count = 14, loss = 0.11544
# validation loss: 0.08470286279916764
# epoch finished: 1
# count = 2, loss = 0.12064
# count = 4, loss = 0.12937
# count = 6, loss = 0.12064
# count = 8, loss = 0.11869
# count = 10, loss = 0.08430
# count = 12, loss = 0.09125
# count = 14, loss = 0.09534
# validation loss: 0.0763450488448143
# epoch finished: 2
# count = 2, loss = 0.11391
# count = 4, loss = 0.10069
# count = 6, loss = 0.09873
# count = 8, loss = 0.10178
# count = 10, loss = 0.11641
# count = 12, loss = 0.09223
# count = 14, loss = 0.09165
# validation loss: 0.07914128452539444
# epoch finished: 3
# count = 2, loss = 0.08466
# count = 4, loss = 0.11263
# count = 6, loss = 0.10172
# count = 8, loss = 0.10516
# count = 10, loss = 0.09843
# count = 12, loss = 0.09505
# count = 14, loss = 0.10470
# validation loss: 0.07949087917804717
# epoch finished: 4
# count = 2, loss = 0.08478
# count = 4, loss = 0.12147
# count = 6, loss = 0.10687
# count = 8, loss = 0.08929
# count = 10, loss = 0.10787
# count = 12, loss = 0.09277
# count = 14, loss = 0.09362
# validation loss: 0.07911836504936218
# epoch finished: 5
# count = 2, loss = 0.10085
# count = 4, loss = 0.10437
# count = 6, loss = 0.08833
# count = 8, loss = 0.10054
# count = 10, loss = 0.09084
# count = 12, loss = 0.11327
# count = 14, loss = 0.09029
# validation loss: 0.08679685592651368
# epoch finished: 6
# count = 2, loss = 0.10940
# count = 4, loss = 0.08348
# count = 6, loss = 0.07855
# count = 8, loss = 0.09922
# count = 10, loss = 0.11295
# count = 12, loss = 0.10818
# count = 14, loss = 0.10657
# validation loss: 0.07654283344745635
# epoch finished: 7
# count = 2, loss = 0.09674
# count = 4, loss = 0.10391
# count = 6, loss = 0.11251
# count = 8, loss = 0.09805
# count = 10, loss = 0.09282
# count = 12, loss = 0.10093
# count = 14, loss = 0.08813
# validation loss: 0.08463973104953766
# epoch finished: 8
# count = 2, loss = 0.10152
# count = 4, loss = 0.08884
# count = 6, loss = 0.09516
# count = 8, loss = 0.10462
# count = 10, loss = 0.09539
# count = 12, loss = 0.07922
# count = 14, loss = 0.09787
# validation loss: 0.08020561188459396
# epoch finished: 9
# count = 2, loss = 0.09469
# count = 4, loss = 0.08764
# count = 6, loss = 0.11316
# count = 8, loss = 0.09866
# count = 10, loss = 0.10019
# count = 12, loss = 0.09086
# count = 14, loss = 0.09057
# validation loss: 0.08895530253648758
# epoch finished: 10
# count = 2, loss = 0.09501
# count = 4, loss = 0.10477
# count = 6, loss = 0.10959
# count = 8, loss = 0.08446
# count = 10, loss = 0.07986
# count = 12, loss = 0.09479
# count = 14, loss = 0.12441
# validation loss: 0.08239613696932793
# epoch finished: 11
# count = 2, loss = 0.09041
# count = 4, loss = 0.10719
# count = 6, loss = 0.09245
# count = 8, loss = 0.09288
# count = 10, loss = 0.09109
# count = 12, loss = 0.09330
# count = 14, loss = 0.09545
# validation loss: 0.08732239156961441
# epoch finished: 12
# count = 2, loss = 0.10232
# count = 4, loss = 0.09105
# count = 6, loss = 0.09845
# count = 8, loss = 0.09549
# count = 10, loss = 0.07736
# count = 12, loss = 0.09952
# count = 14, loss = 0.09706
# validation loss: 0.08221426010131835
# epoch finished: 13
# count = 2, loss = 0.08413
# count = 4, loss = 0.08896
# count = 6, loss = 0.09225
# count = 8, loss = 0.10485
# count = 10, loss = 0.09677
# count = 12, loss = 0.08806
# count = 14, loss = 0.10563
# validation loss: 0.0829360008239746
# epoch finished: 14
# count = 2, loss = 0.08839
# count = 4, loss = 0.08653
# count = 6, loss = 0.10104
# count = 8, loss = 0.08509
# count = 10, loss = 0.10970
# count = 12, loss = 0.08706
# count = 14, loss = 0.09649
# validation loss: 0.08056281358003617
# epoch finished: 15
# count = 2, loss = 0.08991
# count = 4, loss = 0.09116
# count = 6, loss = 0.10529
# count = 8, loss = 0.09153
# count = 10, loss = 0.09368
# count = 12, loss = 0.08765
# count = 14, loss = 0.09671
# validation loss: 0.08794207274913787
# epoch finished: 16
# count = 2, loss = 0.10114
# count = 4, loss = 0.09680
# count = 6, loss = 0.08657
# count = 8, loss = 0.10283
# count = 10, loss = 0.09092
# count = 12, loss = 0.08013
# count = 14, loss = 0.07577
# validation loss: 0.08339875042438508
# epoch finished: 17
# count = 2, loss = 0.08553
# count = 4, loss = 0.09428
# count = 6, loss = 0.08437
# count = 8, loss = 0.09864
# count = 10, loss = 0.10125
# count = 12, loss = 0.10056
# count = 14, loss = 0.09078
# validation loss: 0.0849191665649414
# epoch finished: 18
# count = 2, loss = 0.09101
# count = 4, loss = 0.09046
# count = 6, loss = 0.08490
# count = 8, loss = 0.09853
# count = 10, loss = 0.08700
# count = 12, loss = 0.09816
# count = 14, loss = 0.10297
# validation loss: 0.09260004609823227
# epoch finished: 19
# count = 2, loss = 0.08863
# count = 4, loss = 0.08997
# count = 6, loss = 0.08949
# count = 8, loss = 0.09760
# count = 10, loss = 0.07116
# count = 12, loss = 0.08294
# count = 14, loss = 0.10307
# validation loss: 0.09884261935949326
# epoch finished: 20

# %%
np.save('val_loss_set2.npy', val_losses)
np.save('train_loss_set2.npy', train_losses)

# %%
from evaluation import QWK_score

vloader = DataLoader(valid_data, valid_indices, cfg, glove_dict)
count = 0
avg_loss = 0
MAE = 0
targets = []
preds = []
with torch.no_grad():
    while vloader.has_next():
        train, label, lenghts = vloader.get_next()
        y = model(train, lenghts)
        #y = y.permute(0, 2, 1)
        #print(label - y)
        
        loss = criterion(y*cfg['score_range'], label*cfg['score_range'])
        
        pred = np.round(y.cpu().numpy() * cfg['score_range'])
        target = np.round(label.cpu().numpy() * cfg['score_range'])

        pred = pred.flatten().astype(int)
        target = target.flatten().astype(int)
        
        targets.append(target)
        preds.append(pred)
        
        #print(target[0])
        #print(preds[0])
        
        count += 1
        avg_loss += loss.item()
        MAE += (y-label).abs().mean().item()
        
        del train, label, y, loss
        
print('validation MSE:', avg_loss / count)
print('validation MAE:', MAE / count)
print('QWK Score:', QWK_score(np.asarray(targets).flatten(), np.asarray(preds).flatten(), min_rating = 0, max_rating = 10))
# Out:
# validation MSE: 0.09905731678009033
# validation MAE: 0.08478720784187317
# QWK Score: 0.4952088546048533

# %%
train_losses
# Out:
# [0.5860781818628311,
#  0.458276629447937,
#  0.17450132220983505,
#  0.1616007462143898,
#  0.119425218552351,
#  0.10403617471456528,
#  0.11544415727257729,
#  0.12063881382346153,
#  0.12936975806951523,
#  0.1206429973244667,
#  0.11869359761476517,
#  0.08430387452244759,
#  0.09124544262886047,
#  0.09534449502825737,
#  0.11391148716211319,
#  0.1006905697286129,
#  0.09873098507523537,
#  0.1017775870859623,
#  0.11640776321291924,
#  0.09222627431154251,
#  0.09164854511618614,
#  0.08466239273548126,
#  0.11262743547558784,
#  0.10171670094132423,
#  0.1051570288836956,
#  0.09843045473098755,
#  0.09505286067724228,
#  0.1046961285173893,
#  0.08478100225329399,
#  0.1214694194495678,
#  0.10686950758099556,
#  0.08928555250167847,
#  0.10787016153335571,
#  0.09276992827653885,
#  0.0936187207698822,
#  0.10085402429103851,
#  0.1043703593313694,
#  0.08833080530166626,
#  0.1005408950150013,
#  0.09083717316389084,
#  0.11326977983117104,
#  0.09029350057244301,
#  0.1094016395509243,
#  0.0834839902818203,
#  0.0785537138581276,
#  0.09922155737876892,
#  0.11295151710510254,
#  0.1081792563199997,
#  0.10656902566552162,
#  0.09673995152115822,
#  0.10390651226043701,
#  0.11250581219792366,
#  0.09805251657962799,
#  0.09282055124640465,
#  0.10093235224485397,
#  0.08812868595123291,
#  0.10151547193527222,
#  0.08883558958768845,
#  0.095155019313097,
#  0.10462488234043121,
#  0.09538611769676208,
#  0.07922230288386345,
#  0.09786718711256981,
#  0.0946890376508236,
#  0.0876435749232769,
#  0.11315882951021194,
#  0.0986580066382885,
#  0.10018758475780487,
#  0.09085800126194954,
#  0.09057094156742096,
#  0.09501306712627411,
#  0.10477497056126595,
#  0.10959263145923615,
#  0.08445626124739647,
#  0.07985560223460197,
#  0.09478747844696045,
#  0.12440785020589828,
#  0.09040698781609535,
#  0.10719121247529984,
#  0.09245112538337708,
#  0.09287536144256592,
#  0.09108756482601166,
#  0.09329979494214058,
#  0.09545065835118294,
#  0.1023169718682766,
#  0.091050885617733,
#  0.09845056757330894,
#  0.09548722580075264,
#  0.07736210152506828,
#  0.09951857104897499,
#  0.09706209227442741,
#  0.08413214609026909,
#  0.08896180614829063,
#  0.0922464057803154,
#  0.10485043749213219,
#  0.0967678464949131,
#  0.0880555622279644,
#  0.1056261956691742,
#  0.08838983252644539,
#  0.08653441071510315,
#  0.10103876143693924,
#  0.08509064838290215,
#  0.10970477014780045,
#  0.08705990761518478,
#  0.09649490565061569,
#  0.0899081602692604,
#  0.09116439893841743,
#  0.10529109090566635,
#  0.09153379499912262,
#  0.09368354082107544,
#  0.08765226230025291,
#  0.09671058133244514,
#  0.10113542899489403,
#  0.0968010164797306,
#  0.08656923845410347,
#  0.10282943025231361,
#  0.09092225506901741,
#  0.08012982457876205,
#  0.07577160000801086,
#  0.08553032949566841,
#  0.0942777469754219,
#  0.08436679467558861,
#  0.09863816574215889,
#  0.10124847665429115,
#  0.10056281089782715,
#  0.09078091010451317,
#  0.09100669994950294,
#  0.09046314656734467,
#  0.08490055426955223,
#  0.09852515906095505,
#  0.0869964212179184,
#  0.09816164150834084,
#  0.10296630859375,
#  0.08862535282969475,
#  0.08997194468975067,
#  0.08948943763971329,
#  0.09759640693664551,
#  0.07116207107901573,
#  0.08293959498405457,
#  0.10307299718260765]

# %%
val_losses
# Out:
# [0.08470286279916764,
#  0.0763450488448143,
#  0.07914128452539444,
#  0.07949087917804717,
#  0.07911836504936218,
#  0.08679685592651368,
#  0.07654283344745635,
#  0.08463973104953766,
#  0.08020561188459396,
#  0.08895530253648758,
#  0.08239613696932793,
#  0.08732239156961441,
#  0.08221426010131835,
#  0.0829360008239746,
#  0.08056281358003617,
#  0.08794207274913787,
#  0.08339875042438508,
#  0.0849191665649414,
#  0.09260004609823227,
#  0.09884261935949326]

# %%
import matplotlib.pyplot as plt
import numpy as np


fig, ax = plt.subplots(figsize=(10, 5))
ax.plot(np.arange(len(train_losses)) / (len(train_losses) // len(val_losses)),train_losses,label='training loss')
ax.plot(np.arange(1,len(val_losses)+1) ,np.array(val_losses) + 0.01,label='validation loss')

ax.set_xlabel('epoch')
ax.set_ylabel('loss value')
ax.legend()
plt.show()

# %%
from dataloader import *
from models import *
model = load_model(LSTM_Score, './models_LSTM/eba117b1400.pt', cfg)
valid_indices = list(range(len(valid_data)))
# Out:
# RuntimeErrorTraceback (most recent call last)
# <ipython-input-9-7d1bb3677812> in <module>()
#       1 from dataloader import *
#       2 from models import *
# ----> 3 model = load_model(LSTM_Score, './models_LSTM/eba117b1400.pt', cfg)
#       4 valid_indices = list(range(len(valid_data)))
#
# ~/cogs118B_final/models.py in load_model(ctor, path, cfg)
#     168     model = ctor(cfg, False)
#     169     model = model.to(torch.device(cfg['device']))
# --> 170     model.load_state_dict(torch.load(path))
#     171     model.eval()
#     172     return model
#
# /opt/conda/lib/python3.6/site-packages/torch/nn/modules/module.py in load_state_dict(self, state_dict, strict)
#     719         if len(error_msgs) > 0:
#     720             raise RuntimeError('Error(s) in loading state_dict for {}:\n\t{}'.format(
# --> 721                                self.__class__.__name__, "\n\t".join(error_msgs)))
#     722
#     723     def parameters(self):
#
# RuntimeError: Error(s) in loading state_dict for LSTM_Score:
# 	Missing key(s) in state_dict: "bn.weight", "bn.bias", "bn.running_mean", "bn.running_var".
# 	Unexpected key(s) in state_dict: "conv.weight", "conv.bias", "fc2.weight", "fc2.bias".
# 	While copying the parameter named "fc1.weight", whose dimensions in the model are torch.Size([1, 256]) and whose dimensions in the checkpoint are torch.Size([64, 256]).
# 	While copying the parameter named "fc1.bias", whose dimensions in the model are torch.Size([1]) and whose dimensions in the checkpoint are torch.Size([64]).

# %%
val_losses
# Out:
# [1.47348153591156,
#  0.6406370401382446,
#  0.39495953917503357,
#  0.32788610458374023,
#  0.46300799399614334,
#  0.4477241486310959,
#  0.38527511805295944,
#  0.40745867043733597,
#  0.4503869116306305,
#  0.4217817857861519,
#  0.3887465298175812,
#  0.3928548991680145,
#  0.42445058375597,
#  0.48021963983774185,
#  0.47371671348810196,
#  0.412605918943882,
#  0.4933035224676132,
#  0.4228593334555626,
#  0.49359291046857834,
#  0.5352080911397934]

# %%
train_losses
# Out:
# [7.9363625049591064,
#  8.973733901977539,
#  4.763446807861328,
#  3.0619534254074097,
#  2.584040403366089,
#  2.0441386699676514,
#  2.1084685921669006,
#  1.6885703206062317,
#  1.531571865081787,
#  1.6946741938591003,
#  1.2110268473625183,
#  1.3063259720802307,
#  0.9987798631191254,
#  0.8282113969326019,
#  0.9221987426280975,
#  0.9459511041641235,
#  0.7851526439189911,
#  0.8722099363803864,
#  0.6612995564937592,
#  0.6654603481292725,
#  0.7896145582199097,
#  0.8583588898181915,
#  0.6742445528507233,
#  0.8870276510715485,
#  0.6685461401939392,
#  0.6565273702144623,
#  0.5628261119127274,
#  0.6644041836261749,
#  0.6435962915420532,
#  0.5441005229949951,
#  0.7773476541042328,
#  0.8098107278347015,
#  0.7732094526290894,
#  0.6991858780384064,
#  0.7715423703193665,
#  0.6842981576919556,
#  0.735701322555542,
#  0.6935223042964935,
#  0.5725542902946472,
#  0.8133407831192017,
#  0.6434799432754517,
#  0.7053241729736328,
#  0.7483589947223663,
#  0.7538842856884003,
#  0.5727023184299469,
#  0.5533912777900696,
#  0.7172544598579407,
#  0.793199896812439,
#  0.7602631151676178,
#  0.6039156317710876,
#  0.7156001329421997,
#  0.7351759076118469,
#  0.6287225633859634,
#  0.6371257305145264,
#  0.6663413643836975,
#  0.6422617137432098,
#  0.5664713978767395,
#  0.6144751310348511,
#  0.8458120822906494,
#  0.6660518646240234,
#  0.7278797626495361,
#  0.561577707529068,
#  0.7475858926773071,
#  0.6672446429729462,
#  0.5535566508769989,
#  0.808163970708847,
#  0.6666949987411499,
#  0.6226764917373657,
#  0.741619735956192,
#  0.7095600962638855,
#  0.6346174776554108,
#  0.70871701836586,
#  0.594302624464035,
#  0.6022291928529739,
#  0.5960790812969208,
#  0.6263956725597382,
#  0.8578766882419586,
#  0.5765599608421326,
#  0.6506688594818115,
#  0.57157763838768,
#  0.7119768261909485,
#  0.6619977951049805,
#  0.7925500273704529,
#  0.5977398753166199,
#  0.5565135329961777,
#  0.6358498334884644,
#  0.7072983682155609,
#  0.6081711947917938,
#  0.6994612812995911,
#  0.6318611204624176,
#  0.6768671870231628,
#  0.6271893978118896,
#  0.5542086064815521,
#  0.6575110256671906,
#  0.6476854383945465,
#  0.5896778702735901,
#  0.5800316035747528,
#  0.6566833853721619,
#  0.5469645857810974,
#  0.6688573658466339,
#  0.5459252893924713,
#  0.5784631371498108,
#  0.7136499881744385,
#  0.7287974655628204,
#  0.5856439471244812,
#  0.5872495174407959,
#  0.7439089119434357,
#  0.5569380521774292,
#  0.6734512448310852,
#  0.7059811651706696,
#  0.5511642247438431,
#  0.5641889572143555,
#  0.5831111073493958,
#  0.6351142227649689,
#  0.5866292417049408,
#  0.7028184533119202,
#  0.5012833625078201,
#  0.6534703075885773,
#  0.8082614243030548,
#  0.6345829963684082,
#  0.6044447124004364,
#  0.5901219546794891,
#  0.6432301104068756,
#  0.6071166098117828,
#  0.6084116995334625,
#  0.682973176240921,
#  0.557640552520752,
#  0.5041004568338394,
#  0.7131587266921997,
#  0.7608007788658142,
#  0.5792563259601593,
#  0.7927272915840149,
#  0.592287003993988,
#  0.6015218794345856,
#  0.6258521676063538,
#  0.5615929365158081,
#  0.6531915068626404,
#  0.5793988108634949,
#  0.7314375638961792,
#  0.7673974335193634]
